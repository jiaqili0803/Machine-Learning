# %%
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_sas('LLCP2021.XPT')

# %%
print(df.columns.tolist())
# Out:
# ['_STATE', 'FMONTH', 'IDATE', 'IMONTH', 'IDAY', 'IYEAR', 'DISPCODE', 'SEQNO', '_PSU', 'CTELENM1', 'PVTRESD1', 'COLGHOUS', 'STATERE1', 'CELPHON1', 'LADULT1', 'COLGSEX', 'NUMADULT', 'LANDSEX', 'NUMMEN', 'NUMWOMEN', 'RESPSLCT', 'SAFETIME', 'CTELNUM1', 'CELLFON5', 'CADULT1', 'CELLSEX', 'PVTRESD3', 'CCLGHOUS', 'CSTATE1', 'LANDLINE', 'HHADULT', 'SEXVAR', 'GENHLTH', 'PHYSHLTH', 'MENTHLTH', 'POORHLTH', 'PRIMINSR', 'PERSDOC3', 'MEDCOST1', 'CHECKUP1', 'EXERANY2', 'BPHIGH6', 'BPMEDS', 'CHOLCHK3', 'TOLDHI3', 'CHOLMED3', 'CVDINFR4', 'CVDCRHD4', 'CVDSTRK3', 'ASTHMA3', 'ASTHNOW', 'CHCSCNCR', 'CHCOCNCR', 'CHCCOPD3', 'ADDEPEV3', 'CHCKDNY2', 'DIABETE4', 'DIABAGE3', 'HAVARTH5', 'ARTHEXER', 'ARTHEDU', 'LMTJOIN3', 'ARTHDIS2', 'JOINPAI2', 'MARITAL', 'EDUCA', 'RENTHOM1', 'NUMHHOL3', 'NUMPHON3', 'CPDEMO1B', 'VETERAN3', 'EMPLOY1', 'CHILDREN', 'INCOME3', 'PREGNANT', 'WEIGHT2', 'HEIGHT3', 'DEAF', 'BLIND', 'DECIDE', 'DIFFWALK', 'DIFFDRES', 'DIFFALON', 'SMOKE100', 'SMOKDAY2', 'USENOW3', 'ECIGNOW1', 'ALCDAY5', 'A
# ...

# %%
sub_df = df[['_MICHD', '_BMI5', 'WTKG3', 'HTM4','_SMOKER3', '_RFDRHV7',
'CVDSTRK3', 'PHYSHLTH', 'MENTHLTH', 'DIFFWALK', '_SEX', '_AGEG5YR', '_RACE',
'DIABETE4', '_TOTINDA', 'GENHLTH', 'ASTHMA3', 'CHCKDNY2', 'CHCSCNCR', '_VEGLT1A']]

# %%
sub_df.columns = ['HeartDisease', 'BMI', 'Weight_kg', 'Height_m', 'Smoking', 'AlcoholDrinking', 
'Stroke', 'PhysicalHealth', 'MentalHealth', 'DiffWalking', 'Sex', 'AgeCategory', 'Race',
'Diabetic', 'PhysicalActivity', 'GenHealth', 'Asthma', 'KidneyDisease', 'SkinCancer', 'VegetableAndFruits']

# %%
new_df = sub_df.dropna()
new_df
# Out:
#         HeartDisease     BMI  Weight_kg  Height_m  Smoking  AlcoholDrinking  \
# 0                2.0  1454.0     3266.0     150.0      3.0              1.0
# 2                1.0  2829.0     7711.0     165.0      4.0              1.0
# 3                2.0  3347.0     8845.0     163.0      4.0              1.0
# 4                1.0  2873.0     9344.0     180.0      4.0              1.0
# 5                2.0  2437.0     8845.0     191.0      3.0              1.0
# ...              ...     ...        ...       ...      ...              ...
# 438687           2.0  2148.0     6985.0     180.0      4.0              1.0
# 438688           2.0  2469.0     6123.0     157.0      3.0              1.0
# 438690           2.0  3068.0     9979.0     180.0      4.0              1.0
# 438691           2.0  2373.0     7938.0     183.0      4.0              1.0
# 438692           2.0  3171.0     8119.0     160.0      4.0              1.0
#
# ...

# %%
new_df.isnull().sum()
# Out:
# HeartDisease          0
# BMI                   0
# Weight_kg             0
# Height_m              0
# Smoking               0
# AlcoholDrinking       0
# Stroke                0
# PhysicalHealth        0
# MentalHealth          0
# DiffWalking           0
# Sex                   0
# AgeCategory           0
# Race                  0
# Diabetic              0
# PhysicalActivity      0
# GenHealth             0
# Asthma                0
# KidneyDisease         0
# SkinCancer            0
# VegetableAndFruits    0
# dtype: int64

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 384219 entries, 0 to 438692
# Data columns (total 20 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   HeartDisease        384219 non-null  float64
#  1   BMI                 384219 non-null  float64
#  2   Weight_kg           384219 non-null  float64
#  3   Height_m            384219 non-null  float64
#  4   Smoking             384219 non-null  float64
#  5   AlcoholDrinking     384219 non-null  float64
#  6   Stroke              384219 non-null  float64
#  7   PhysicalHealth      384219 non-null  float64
#  8   MentalHealth        384219 non-null  float64
#  9   DiffWalking         384219 non-null  float64
#  10  Sex                 384219 non-null  float64
#  11  AgeCategory         384219 non-null  float64
#  12  Race                384219 non-null  float64
#  13  Diabetic            384219 non-null  float64
#  14  PhysicalActivity    384219 non-null  float64
# ...

# %%
new_df.columns
# Out:
# Index(['HeartDisease', 'BMI', 'Weight_kg', 'Height_m', 'Smoking',
#        'AlcoholDrinking', 'Stroke', 'PhysicalHealth', 'MentalHealth',
#        'DiffWalking', 'Sex', 'AgeCategory', 'Race', 'Diabetic',
#        'PhysicalActivity', 'GenHealth', 'Asthma', 'KidneyDisease',
#        'SkinCancer', 'VegetableAndFruits'],
#       dtype='object')

# %% [markdown]
# ##### Heart Disease

# %%
new_df['HeartDisease'].describe()
# Out:
# count    384219.000000
# mean          1.915775
# std           0.277726
# min           1.000000
# 25%           2.000000
# 50%           2.000000
# 75%           2.000000
# max           2.000000
# Name: HeartDisease, dtype: float64

# %%
# 1 有病 2 没病
new_df['HeartDisease'].unique()
# Out:
# array([2., 1.])

# %%
new_df[new_df['HeartDisease'] == 2.0]
# Out:
#         HeartDisease     BMI  Weight_kg  Height_m  Smoking  AlcoholDrinking  \
# 0                2.0  1454.0     3266.0     150.0      3.0              1.0
# 3                2.0  3347.0     8845.0     163.0      4.0              1.0
# 5                2.0  2437.0     8845.0     191.0      3.0              1.0
# 6                2.0  4611.0    15422.0     183.0      4.0              1.0
# 9                2.0  3994.0    10886.0     165.0      3.0              1.0
# ...              ...     ...        ...       ...      ...              ...
# 438687           2.0  2148.0     6985.0     180.0      4.0              1.0
# 438688           2.0  2469.0     6123.0     157.0      3.0              1.0
# 438690           2.0  3068.0     9979.0     180.0      4.0              1.0
# 438691           2.0  2373.0     7938.0     183.0      4.0              1.0
# 438692           2.0  3171.0     8119.0     160.0      4.0              1.0
#
# ...

# %%
def heart_disease(x):
    if x == 2.0:
        return 0
    elif x == 1.0:
        return 1

new_df['HeartDisease'] = new_df['HeartDisease'].apply(heart_disease)
new_df
# Out:
#         HeartDisease     BMI  Weight_kg  Height_m  Smoking  AlcoholDrinking  \
# 0                  0  1454.0     3266.0     150.0      3.0              1.0
# 2                  1  2829.0     7711.0     165.0      4.0              1.0
# 3                  0  3347.0     8845.0     163.0      4.0              1.0
# 4                  1  2873.0     9344.0     180.0      4.0              1.0
# 5                  0  2437.0     8845.0     191.0      3.0              1.0
# ...              ...     ...        ...       ...      ...              ...
# 438687             0  2148.0     6985.0     180.0      4.0              1.0
# 438688             0  2469.0     6123.0     157.0      3.0              1.0
# 438690             0  3068.0     9979.0     180.0      4.0              1.0
# 438691             0  2373.0     7938.0     183.0      4.0              1.0
# 438692             0  3171.0     8119.0     160.0      4.0              1.0
#
# ...

# %%
new_df['HeartDisease'].unique()
# Out:
# array([0, 1])

# %% [markdown]
# ##### Smoking

# %% [markdown]
# Have you smoked at least 100 cigarettes in your entire life? [Note: 5 packs = 100 cigarettes]
# 1 yes 0 no

# %%
new_df['Smoking'].describe()
# Out:
# count    384219.000000
# mean          3.436761
# std           1.139505
# min           1.000000
# 25%           3.000000
# 50%           4.000000
# 75%           4.000000
# max           9.000000
# Name: Smoking, dtype: float64

# %%
new_df['Smoking'].unique()
# Out:
# array([3., 4., 2., 1., 9.])

# %%
def smoking(x):
    if x == 1.0 or x == 2.0 or x == 3.0:
        return 1
    elif x == 4.0:
        return 0
    elif x == 9.0:
        return None

new_df['Smoking'] = new_df['Smoking'].apply(smoking)
new_df
# Out:
#         HeartDisease     BMI  Weight_kg  Height_m  Smoking  AlcoholDrinking  \
# 0                  0  1454.0     3266.0     150.0      1.0              1.0
# 2                  1  2829.0     7711.0     165.0      0.0              1.0
# 3                  0  3347.0     8845.0     163.0      0.0              1.0
# 4                  1  2873.0     9344.0     180.0      0.0              1.0
# 5                  0  2437.0     8845.0     191.0      1.0              1.0
# ...              ...     ...        ...       ...      ...              ...
# 438687             0  2148.0     6985.0     180.0      0.0              1.0
# 438688             0  2469.0     6123.0     157.0      1.0              1.0
# 438690             0  3068.0     9979.0     180.0      0.0              1.0
# 438691             0  2373.0     7938.0     183.0      0.0              1.0
# 438692             0  3171.0     8119.0     160.0      0.0              1.0
#
# ...

# %%
new_df['Smoking'].unique()
# Out:
# array([ 1.,  0., nan])

# %%
new_df[new_df['Smoking'].isna()]
# Out:
#         HeartDisease     BMI  Weight_kg  Height_m  Smoking  AlcoholDrinking  \
# 224                0  2455.0     6486.0     163.0      NaN              1.0
# 241                1  3043.0    11340.0     193.0      NaN              1.0
# 324                1  3141.0     8301.0     163.0      NaN              9.0
# 371                0  1974.0     5216.0     163.0      NaN              9.0
# 535                0  2278.0     7620.0     183.0      NaN              1.0
# ...              ...     ...        ...       ...      ...              ...
# 438085             0  2976.0     8618.0     170.0      NaN              2.0
# 438208             0  2437.0     7484.0     175.0      NaN              9.0
# 438270             0  2090.0     5352.0     160.0      NaN              9.0
# 438311             1  4573.0    11340.0     157.0      NaN              9.0
# 438666             0  3119.0    10433.0     183.0      NaN              9.0
#
# ...

# %%
new_df = new_df.dropna()

# %%
new_df['Smoking'].unique()
# Out:
# array([1., 0.])

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 378988 entries, 0 to 438692
# Data columns (total 20 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   HeartDisease        378988 non-null  int64
#  1   BMI                 378988 non-null  float64
#  2   Weight_kg           378988 non-null  float64
#  3   Height_m            378988 non-null  float64
#  4   Smoking             378988 non-null  float64
#  5   AlcoholDrinking     378988 non-null  float64
#  6   Stroke              378988 non-null  float64
#  7   PhysicalHealth      378988 non-null  float64
#  8   MentalHealth        378988 non-null  float64
#  9   DiffWalking         378988 non-null  float64
#  10  Sex                 378988 non-null  float64
#  11  AgeCategory         378988 non-null  float64
#  12  Race                378988 non-null  float64
#  13  Diabetic            378988 non-null  float64
#  14  PhysicalActivity    378988 non-null  float64
# ...

# %% [markdown]
# ##### AlcoholDrinking
# Heavy drinkers (adult men having more than 14 drinks per week and adult women having more than 7 drinks per week

# %%
new_df['AlcoholDrinking'].unique()
# Out:
# array([1., 9., 2.])

# %%
def drinking(x):
    if x == 1.0:
        return 0
    elif x == 2.0:
        return 1
    elif x == 9.0:
        return None

new_df['AlcoholDrinking'] = new_df['AlcoholDrinking'].apply(drinking)

# %%
new_df['AlcoholDrinking'].unique()
# Out:
# array([ 0., nan,  1.])

# %%
new_df = new_df.dropna()

# %%
new_df['AlcoholDrinking'].unique()
# Out:
# array([0., 1.])

# %% [markdown]
# ##### Stroke
# (Ever told) (you had) a stroke?

# %%
new_df['Stroke'].unique()
# Out:
# array([2., 1., 7., 9.])

# %%
def stroke(x):
    if x == 1.0:
        return 1
    elif x == 2.0:
        return 0
    elif x == 9.0 or x == 7.0:
        return None

new_df['Stroke'] = new_df['Stroke'].apply(stroke)

# %%
new_df['Stroke'].isnull().sum()
# Out:
# 787

# %%
new_df = new_df.dropna()

# %%
new_df.isnull().sum()
# Out:
# HeartDisease          0
# BMI                   0
# Weight_kg             0
# Height_m              0
# Smoking               0
# AlcoholDrinking       0
# Stroke                0
# PhysicalHealth        0
# MentalHealth          0
# DiffWalking           0
# Sex                   0
# AgeCategory           0
# Race                  0
# Diabetic              0
# PhysicalActivity      0
# GenHealth             0
# Asthma                0
# KidneyDisease         0
# SkinCancer            0
# VegetableAndFruits    0
# dtype: int64

# %% [markdown]
# ##### PhysicalHealth
# Now thinking about your physical health, which includes physical illness and injury,
# for how many days during the past 30 days was your physical health not good? (0-30 days)

# %%
new_df['PhysicalHealth'].describe()
# Out:
# count    367898.000000
# mean         62.823244
# std          36.417341
# min           1.000000
# 25%          21.000000
# 50%          88.000000
# 75%          88.000000
# max          99.000000
# Name: PhysicalHealth, dtype: float64

# %% [markdown]
# ##### MentalHealth
# Thinking about your mental health, for how many days during the past 30 days was your mental health not good? (0-30 days)

# %%
new_df['MentalHealth'].describe()
# Out:
# count    367898.000000
# mean         59.265745
# std          37.709491
# min           1.000000
# 25%          14.000000
# 50%          88.000000
# 75%          88.000000
# max          99.000000
# Name: MentalHealth, dtype: float64

# %%
new_df['MentalHealth'].unique()
# Out:
# array([10., 88.,  5., 25., 77., 14.,  2.,  3.,  7.,  1., 30., 20.,  8.,
#        15.,  4., 99., 21., 28., 24., 12.,  6., 22., 27.,  9., 18., 13.,
#        17., 16., 19., 29., 23., 26., 11.])

# %% [markdown]
# ##### DiffWalking
# During the past month, other than your regular job, did you participate in any physical activities or exercises such as running, calisthenics, golf, gardening, or walking for exercise?
# 1 Yes 2 No 7 Don’t know / Not sure 9 Refused

# %%
new_df['DiffWalking'].unique()
# Out:
# array([2., 1., 7., 9.])

# %%
def exercise(x):
    if x == 1.0:
        return 1
    elif x == 2.0:
        return 0
    elif x == 9.0 or x == 7.0:
        return None

new_df['DiffWalking'] = new_df['DiffWalking'].apply(exercise)

# %%
new_df['DiffWalking'].unique()
# Out:
# array([ 0.,  1., nan])

# %%
new_df['DiffWalking'].isnull().sum()
# Out:
# 991

# %%
new_df = new_df.dropna()

# %%
new_df['DiffWalking'].unique()
# Out:
# array([0., 1.])

# %% [markdown]
# ##### Sex
# Calculated variable for calculated sex variable

# %%
new_df['Sex'].unique()
# Out:
# array([2., 1.])

# %%
def sex(x):
    if x == 1.0:
        return 1
    elif x == 2.0:
        return 0

new_df['Sex'] = new_df['Sex'].apply(sex)

# %% [markdown]
# * 1 Male, 2 Female

# %%
new_df['Sex'].unique()
# Out:
# array([0, 1])

# %%
new_df['Sex'].describe()
# Out:
# count    366907.000000
# mean          0.481585
# std           0.499661
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           1.000000
# max           1.000000
# Name: Sex, dtype: float64

# %% [markdown]
# ##### AgeCategory
# 1: 18-24; 2: 25-29; 3: 30-34; 4: 35-39; 5: 40-44; 6: 45-49; 7: 50-54; 8: 55-59; 9: 60-64; 10: 65-69; 11: 70-74; 12: 75-79; 13: 80+; 14 not found

# %%
new_df['AgeCategory'].describe()
# Out:
# count    366907.000000
# mean          7.679139
# std           3.600308
# min           1.000000
# 25%           5.000000
# 50%           8.000000
# 75%          11.000000
# max          14.000000
# Name: AgeCategory, dtype: float64

# %%
new_df['AgeCategory'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ##### Race
# 我看好多notebook都drop了 race
# 具体内容看pdf

# %% [markdown]
# ##### Diabetic
# 1 Yes  2 Yes, but female told only during pregnancy 3 No 4 No, prediabetes or borderline diabetes 7 Don’t know / Not sure 9 Refused

# %%
new_df['Diabetic'].unique()
# Out:
# array([3., 1., 4., 2., 7., 9.])

# %%
# 0 no, 1 yes, 2 female only during pregnancy
def diabetic(x):
    if x == 3.0 or x == 4.0:
        return 0
    elif x == 1.0:
        return 1
    elif x == 9 or x == 7 or x == 2:
        return None

new_df['Diabetic'] = new_df['Diabetic'].apply(diabetic)

# %%
new_df['Diabetic'].unique()
# Out:
# array([ 0.,  1., nan])

# %%
new_df['Diabetic'].isnull().sum()
# Out:
# 3528

# %%
new_df = new_df.dropna()

# %%
new_df.isnull().sum()
# Out:
# HeartDisease          0
# BMI                   0
# Weight_kg             0
# Height_m              0
# Smoking               0
# AlcoholDrinking       0
# Stroke                0
# PhysicalHealth        0
# MentalHealth          0
# DiffWalking           0
# Sex                   0
# AgeCategory           0
# Race                  0
# Diabetic              0
# PhysicalActivity      0
# GenHealth             0
# Asthma                0
# KidneyDisease         0
# SkinCancer            0
# VegetableAndFruits    0
# dtype: int64

# %% [markdown]
# ##### PhysicalActivity
# Calculated variable for adults who reported doing physical activity or exercise during the past 30 days other than their regular job.

# %%
new_df['PhysicalActivity'].unique()
# Out:
# array([2., 1., 9.])

# %%
# 0 no, 1 yes
def physical(x):
    if x == 1.0:
        return 1
    elif x == 2.0:
        return 0

new_df['PhysicalActivity'] = new_df['PhysicalActivity'].apply(physical)

# %%
new_df['PhysicalActivity'].unique()
# Out:
# array([ 0.,  1., nan])

# %% [markdown]
# ##### GenHealth
# Would you say that in general your health is—
# 1 Excellent 2 Very Good 3 Good  4 Fair 5 Poor ;
# Do not read: 7 Don’t know/Not sure 9 Refused

# %%
new_df['GenHealth'].unique()
# Out:
# array([5., 2., 3., 4., 1., 7., 9.])

# %%
def genhealth(x):
    if x == 7.0 or x == 9.0:
        return None
    elif x == 5.0:
        return 5
    elif x == 3.0:
        return 3
    elif x == 4.0:
        return 4
    elif x == 1.0:
        return 1
    elif x == 2.0:
        return 2
new_df['GenHealth'] = new_df['GenHealth'].apply(genhealth)

# %%
new_df = new_df.dropna()

# %%
new_df['GenHealth'].unique()
# Out:
# array([5., 2., 3., 4., 1.])

# %% [markdown]
# ##### Asthma
# (Ever told) (you had) asthma?
# 1 Yes    2 No 7 Don’t know / Not sure 9 Refused

# %%
new_df['Asthma'].unique()
# Out:
# array([1., 2., 7., 9.])

# %%
# 1 yes 0 no
def asthma(x):
    if x == 7.0 or x == 9.0:
        return None
    elif x == 1.0:
        return 1
    elif x == 2.0:
        return 0

new_df['Asthma'] = new_df['Asthma'].apply(asthma)

# %%
new_df['Asthma'].unique()
# Out:
# array([ 1.,  0., nan])

# %%
new_df = new_df.dropna()

# %%
new_df.isnull().sum()
# Out:
# HeartDisease          0
# BMI                   0
# Weight_kg             0
# Height_m              0
# Smoking               0
# AlcoholDrinking       0
# Stroke                0
# PhysicalHealth        0
# MentalHealth          0
# DiffWalking           0
# Sex                   0
# AgeCategory           0
# Race                  0
# Diabetic              0
# PhysicalActivity      0
# GenHealth             0
# Asthma                0
# KidneyDisease         0
# SkinCancer            0
# VegetableAndFruits    0
# dtype: int64

# %% [markdown]
# ##### KidneyDisease
# Not including kidney stones, bladder infection or incontinence, were you ever told you had kidney disease?
#
# 1 Yes 2 No 7 Don’t know / Not sure 9 Refused

# %%
new_df['KidneyDisease'].unique()
# Out:
# array([2., 1., 9., 7.])

# %%
# 1 yes 0 no
def kidney(x):
    if x == 7.0 or x == 9.0:
        return None
    elif x == 1.0:
        return 1
    elif x == 2.0:
        return 0

new_df['KidneyDisease'] = new_df['KidneyDisease'].apply(kidney)

# %%
new_df['KidneyDisease'].unique()
# Out:
# array([ 0.,  1., nan])

# %%
new_df = new_df.dropna()

# %%
new_df.isnull().sum()
# Out:
# HeartDisease          0
# BMI                   0
# Weight_kg             0
# Height_m              0
# Smoking               0
# AlcoholDrinking       0
# Stroke                0
# PhysicalHealth        0
# MentalHealth          0
# DiffWalking           0
# Sex                   0
# AgeCategory           0
# Race                  0
# Diabetic              0
# PhysicalActivity      0
# GenHealth             0
# Asthma                0
# KidneyDisease         0
# SkinCancer            0
# VegetableAndFruits    0
# dtype: int64

# %% [markdown]
# ##### SkinCancer
# (Ever told) (you had) any other types of cancer?
#
# 1 Yes 2 No 7 Don’t know / Not sure 9 Refused

# %%
new_df['SkinCancer'].unique()
# Out:
# array([2., 1., 7., 9.])

# %%
new_df['SkinCancer'] = new_df['SkinCancer'].apply(kidney)

# %%
new_df['SkinCancer'].unique()
# Out:
# array([ 0.,  1., nan])

# %%
new_df = new_df.dropna()

# %%
new_df['SkinCancer'].unique()
# Out:
# array([0., 1.])

# %% [markdown]
# ##### VegetableAndFruits
# Calculated variable for consume vegetables 1 or more times per day
#
# 1 Consumed vegetables one or more times per day; 2 Consumed vegetables less than one time per day; 9 missing

# %%
new_df['VegetableAndFruits'].unique()
# Out:
# array([1., 2., 9.])

# %%
def veg(x):
    if x == 9.0:
        return None
    elif x == 1.0:
        return 1
    elif x == 2.0:
        return 0

new_df['VegetableAndFruits'] = new_df['VegetableAndFruits'].apply(veg)

# %%
new_df['VegetableAndFruits'].unique()
# Out:
# array([ 1.,  0., nan])

# %%
new_df = new_df.dropna()

# %%
new_df
# Out:
#         HeartDisease     BMI  Weight_kg  Height_m  Smoking  AlcoholDrinking  \
# 0                  0  1454.0     3266.0     150.0      1.0              0.0
# 2                  1  2829.0     7711.0     165.0      0.0              0.0
# 3                  0  3347.0     8845.0     163.0      0.0              0.0
# 4                  1  2873.0     9344.0     180.0      0.0              0.0
# 5                  0  2437.0     8845.0     191.0      1.0              0.0
# ...              ...     ...        ...       ...      ...              ...
# 438686             0  2905.0     8165.0     168.0      0.0              0.0
# 438687             0  2148.0     6985.0     180.0      0.0              0.0
# 438690             0  3068.0     9979.0     180.0      0.0              0.0
# 438691             0  2373.0     7938.0     183.0      0.0              0.0
# 438692             0  3171.0     8119.0     160.0      0.0              0.0
#
# ...

# %% [markdown]
# ##### calculate bmi

# %%
new_df['BMI_new'] = (new_df['Weight_kg']/100) / ((new_df['Height_m'] / 100) * (new_df['Height_m'] / 100))

# %%
new_df
# Out:
#         HeartDisease     BMI  Weight_kg  Height_m  Smoking  AlcoholDrinking  \
# 0                  0  1454.0     3266.0     150.0      1.0              0.0
# 2                  1  2829.0     7711.0     165.0      0.0              0.0
# 3                  0  3347.0     8845.0     163.0      0.0              0.0
# 4                  1  2873.0     9344.0     180.0      0.0              0.0
# 5                  0  2437.0     8845.0     191.0      1.0              0.0
# ...              ...     ...        ...       ...      ...              ...
# 438686             0  2905.0     8165.0     168.0      0.0              0.0
# 438687             0  2148.0     6985.0     180.0      0.0              0.0
# 438690             0  3068.0     9979.0     180.0      0.0              0.0
# 438691             0  2373.0     7938.0     183.0      0.0              0.0
# 438692             0  3171.0     8119.0     160.0      0.0              0.0
#
# ...

# %%
new_df.columns
# Out:
# Index(['HeartDisease', 'BMI', 'Weight_kg', 'Height_m', 'Smoking',
#        'AlcoholDrinking', 'Stroke', 'PhysicalHealth', 'MentalHealth',
#        'DiffWalking', 'Sex', 'AgeCategory', 'Race', 'Diabetic',
#        'PhysicalActivity', 'GenHealth', 'Asthma', 'KidneyDisease',
#        'SkinCancer', 'VegetableAndFruits', 'BMI_new'],
#       dtype='object')

# %%
final_df = new_df[['HeartDisease','Smoking',
       'AlcoholDrinking', 'Stroke', 'PhysicalHealth', 'MentalHealth',
       'DiffWalking', 'Sex', 'AgeCategory', 'Race', 'Diabetic',
       'PhysicalActivity', 'GenHealth', 'Asthma', 'KidneyDisease',
       'SkinCancer', 'VegetableAndFruits', 'BMI_new']]

# %%
final_df.to_csv('data_cleaned.csv', index=False)

# %%
cleaned = pd.read_csv("data_cleaned.csv")
cleaned
# Out:
#         HeartDisease  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0                  0      1.0              0.0     0.0            20.0
# 1                  1      0.0              0.0     0.0            88.0
# 2                  0      0.0              0.0     0.0            88.0
# 3                  1      0.0              0.0     1.0            30.0
# 4                  0      1.0              0.0     0.0            88.0
# ...              ...      ...              ...     ...             ...
# 334200             0      0.0              0.0     0.0             5.0
# 334201             0      0.0              0.0     0.0            88.0
# 334202             0      0.0              0.0     0.0            88.0
# 334203             0      0.0              0.0     0.0            88.0
# 334204             0      0.0              0.0     0.0             2.0
#
#         MentalHealth  DiffWalking  Sex  AgeCategory  Race  Diabetic  \
# ...

# %%
cleaned['BMI_new']
# Out:
# 0         14.515556
# 1         28.323232
# 2         33.290677
# 3         28.839506
# 4         24.245498
#             ...
# 334200    28.929280
# 334201    21.558642
# 334202    30.799383
# 334203    23.703306
# 334204    31.714844
# Name: BMI_new, Length: 334205, dtype: float64

# %%
import seaborn as sns
sns.boxenplot(cleaned['BMI_new'])
# Out:
# <AxesSubplot:>

# %%
cleaned.isnull().sum()
# Out:
# HeartDisease          0
# Smoking               0
# AlcoholDrinking       0
# Stroke                0
# PhysicalHealth        0
# MentalHealth          0
# DiffWalking           0
# Sex                   0
# AgeCategory           0
# Race                  0
# Diabetic              0
# PhysicalActivity      0
# GenHealth             0
# Asthma                0
# KidneyDisease         0
# SkinCancer            0
# VegetableAndFruits    0
# BMI_new               0
# dtype: int64

# %%
cleaned
# Out:
#         HeartDisease  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0                  0      1.0              0.0     0.0            20.0
# 1                  1      0.0              0.0     0.0            88.0
# 2                  0      0.0              0.0     0.0            88.0
# 3                  1      0.0              0.0     1.0            30.0
# 4                  0      1.0              0.0     0.0            88.0
# ...              ...      ...              ...     ...             ...
# 334200             0      0.0              0.0     0.0             5.0
# 334201             0      0.0              0.0     0.0            88.0
# 334202             0      0.0              0.0     0.0            88.0
# 334203             0      0.0              0.0     0.0            88.0
# 334204             0      0.0              0.0     0.0             2.0
#
#         MentalHealth  DiffWalking  Sex  AgeCategory  Race  Diabetic  \
# ...

# %%
df = pd.read_csv('data_cleaned.csv')

# %%
df.loc[(df.PhysicalHealth == 88.0),'PhysicalHealth'] = 0
df.loc[(df.PhysicalHealth == 77.0),'PhysicalHealth'] = 0
df.loc[(df.PhysicalHealth == 99.0),'PhysicalHealth'] = 0
df.loc[(df.MentalHealth == 88.0),'MentalHealth'] = 0
df.loc[(df.MentalHealth == 77.0),'MentalHealth'] = 0
df.loc[(df.MentalHealth == 99.0),'MentalHealth'] = 0

# %%
df.isna().any()
# Out:
# HeartDisease          False
# Smoking               False
# AlcoholDrinking       False
# Stroke                False
# PhysicalHealth        False
# MentalHealth          False
# DiffWalking           False
# Sex                   False
# AgeCategory           False
# Race                  False
# Diabetic              False
# PhysicalActivity      False
# GenHealth             False
# Asthma                False
# KidneyDisease         False
# SkinCancer            False
# VegetableAndFruits    False
# BMI_new               False
# dtype: bool

# %%
df.shape
# Out:
# (334205, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 334205 entries, 0 to 334204
# Data columns (total 18 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   HeartDisease        334205 non-null  int64
#  1   Smoking             334205 non-null  float64
#  2   AlcoholDrinking     334205 non-null  float64
#  3   Stroke              334205 non-null  float64
#  4   PhysicalHealth      334205 non-null  float64
#  5   MentalHealth        334205 non-null  float64
#  6   DiffWalking         334205 non-null  float64
#  7   Sex                 334205 non-null  int64
#  8   AgeCategory         334205 non-null  float64
#  9   Race                334205 non-null  float64
#  10  Diabetic            334205 non-null  float64
#  11  PhysicalActivity    334205 non-null  float64
#  12  GenHealth           334205 non-null  float64
#  13  Asthma              334205 non-null  float64
#  14  KidneyDisease       334205 non-null  float64
# ...

# %%
df.to_csv('data_cleaned.csv', index=False)
